# %%
import gzip
import json
import re
import os
import sys
import numpy as np
import pandas as pd
pd.options.display.float_format = '{:,}'.format

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
def load_data(file_name, head = 500):
    count = 0
    data = []
    with gzip.open(file_name) as fin:
        for l in fin:
            d = json.loads(l)
            count += 1
            data.append(d)

            # break if reaches the 100th line
            if (head is not None) and (count > head):
                break
    return data


indir = '/content/drive/MyDrive/Capstone/dataset/'
books = load_data(os.path.join(indir, 'goodreads_books.json.gz'))
books = pd.DataFrame(books )
print('=== First 5 records ===')
display(books)
# Out:
# === First 5 records ===
#            isbn text_reviews_count    series country_code language_code  \
# 0    0312853122                  1        []           US
# 1    0743509986                  6        []           US
# 2                                7  [189911]           US           eng
# 3    0743294297               3282        []           US           eng
# 4    0850308712                  5        []           US
# ..          ...                ...       ...          ...           ...
# 496                             13        []           US           spa
# 497                              1        []           US
# 498  1417908378                  2        []           US
# 499  157023177X                  2        []           US
# 500  0786928840                 13        []           US           eng
#
#                                        popular_shelves        asin is_ebook  \
# 0    [{'count': '3', 'name': 'to-read'}, {'count': ...                false
# 1    [{'count': '2634', 'name': 'to-read'}, {'count...                false
# 2    [{'count': '58', 'name': 'to-read'}, {'count':...  B00071IKUY    false
# 3    [{'count': '7615', 'name': 'to-read'}, {'count...                false
# 4    [{'count': '32', 'name': 'to-read'}, {'count':...                false
# ..                                                 ...         ...      ...
# 496  [{'count': '434', 'name': 'to-read'}, {'count'...                false
# 497                [{'count': '2', 'name': 'to-read'}]                false
# 498  [{'count': '6', 'name': 'to-read'}, {'count': ...                false
# 499  [{'count': '2', 'name': 'to-read'}, {'count': ...                false
# 500  [{'count': '101', 'name': 'to-read'}, {'count'...                false
#
#     average_rating kindle_asin  ... publication_month edition_information  \
# 0             4.00              ...                 9
# 1             3.23  B000FC0PBC  ...                10            Abridged
# 2             4.03              ...                     Book Club Edition
# 3             3.49  B002ENBLOK  ...                 7
# 4             3.40              ...
# ..             ...         ...  ...               ...                 ...
# 496           3.89  B007VDWD2C  ...                 5
# 497           3.67              ...
# 498           4.00              ...
# 499           3.00  B01A7N3WUY  ...                12
# 500           4.04              ...
#
#     publication_year                                                url  \
# 0               1984  https://www.goodreads.com/book/show/5333265-w-...
# 1               2001  https://www.goodreads.com/book/show/1333909.Go...
# 2               1987  https://www.goodreads.com/book/show/7327624-th...
# 3               2009  https://www.goodreads.com/book/show/6066819-be...
# 4                     https://www.goodreads.com/book/show/287140.Run...
# ..               ...                                                ...
# 496             2011  https://www.goodreads.com/book/show/12158822-l...
# 497             2008  https://www.goodreads.com/book/show/2864845-ak...
# 498                   https://www.goodreads.com/book/show/802870.Irv...
# 499             2001  https://www.goodreads.com/book/show/4608421-st...
# 500                   https://www.goodreads.com/book/show/802872.Dra...
#
#                                              image_url   book_id  \
# 0    https://images.gr-assets.com/books/1310220028m...   5333265
# 1    https://s.gr-assets.com/assets/nophoto/book/11...   1333909
# 2    https://images.gr-assets.com/books/1304100136m...   7327624
# 3    https://s.gr-assets.com/assets/nophoto/book/11...   6066819
# 4    https://images.gr-assets.com/books/1413219371m...    287140
# ..                                                 ...       ...
# 496  https://images.gr-assets.com/books/1364828503m...  12158822
# 497  https://s.gr-assets.com/assets/nophoto/book/11...   2864845
# 498  https://s.gr-assets.com/assets/nophoto/book/11...    802870
# 499  https://s.gr-assets.com/assets/nophoto/book/11...   4608421
# 500  https://s.gr-assets.com/assets/nophoto/book/11...    802872
#
#     ratings_count  work_id                                              title  \
# 0               3  5400751                        W.C. Fields: A Life on Film
# 1              10  1323437                                        Good Harbor
# 2             140  8948723  The Unschooled Wizard (Sun Wolf and Starhawk, ...
# 3           51184  6243154                               Best Friends Forever
# 4              15   278577  Runic Astrology: Starcraft and Timekeeping in ...
# ..            ...      ...                                                ...
# 496            75  7155273                                       La acabadora
# 497             3  2890987                                 Akhir Sebuah Mimpi
# 498             2   788830                             Irvin Cobb at His Best
# 499             3  4658298                       Stone Gods, Wooden Elephants
# 500           555   788832                  Draconomicon: The Book of Dragons
#
#                                   title_without_series
# 0                          W.C. Fields: A Life on Film
# 1                                          Good Harbor
# 2    The Unschooled Wizard (Sun Wolf and Starhawk, ...
# 3                                 Best Friends Forever
# 4    Runic Astrology: Starcraft and Timekeeping in ...
# ..                                                 ...
# 496                                       La acabadora
# 497                                 Akhir Sebuah Mimpi
# 498                             Irvin Cobb at His Best
# 499                       Stone Gods, Wooden Elephants
# 500                  Draconomicon: The Book of Dragons
#
# [501 rows x 29 columns]
